# %% [markdown]
# # Language Modelling 2
#
# My notes for the following videos by Andrej Karpathy:
#
# - [_Building makemore Part 3: Activations & Gradients, BatchNorm_](https://www.youtube.com/watch?v=P6sfmUTpUmc)
#
# We will try to get a better understanding of the tools with which we are working and optimize our previous model.

# %%
# BUILD AND SPLIT DATA

import torch
import torch.nn.functional as F

words = open('names.txt', 'r').read().splitlines()

# Get all possible characters and create char to int mapping
chars = sorted(list(set(''.join(words))))
stoi = {s: i + 1 for i, s in enumerate(chars)}
stoi['.'] = 0
itos = {i: s for s, i in stoi.items()}

# Hyperparameters
n = 3 # context length
m = 10 # embedding dimension
k = 200 # hidden layer size

def build_dataset(words):
    block_size = n # context length
    X, Y = [], []
    for w in words:
        context = [0] * block_size
        for ch in w + '.':
            ix = stoi[ch]
            X.append(context)
            Y.append(ix)
            context = context[1:] + [ix]

    X  = torch.tensor(X)
    Y = torch.tensor(Y)
    return X, Y

import random
random.shuffle(words)
n1 = int(0.8*len(words))
n2 = int(0.9*len(words))

Xtr, Ytr = build_dataset(words[:n1])
Xdev, Ydev = build_dataset(words[n1:n2])
Xte, Yte = build_dataset(words[n2:])

# %%
# BUILD NN

C = torch.randn((27, m))
W1 = torch.randn((m * n, k)) # second parameter is hidden layer size
b1 = torch.randn(k)
W2 = torch.randn(k, 27) * 0.01
b2 = torch.randn(27) * 0
parameters = [C, W1, b1, W2, b2]

for p in parameters:
    p.requires_grad = True

# %%
# TRAINING

max_steps = 200000
sgd_batch_size = 32

# Keep track of learning rate performance and/or optimization
# lre = torch.linspace(-3, 0, 1000)
# lrs = 10**lre

lri = []
lossi = []
stepi = []

for i in range(max_steps):
    # SGD batch selection
    ix = torch.randint(0, Xtr.shape[0], (sgd_batch_size,))
    
    # Forward Pass
    emb = C[Xtr[ix]] # Input (32, 3, 2)
    h = torch.tanh(emb.view(-1, m * n) @ W1 + b1) # First layer output (32, 100)
    logits = h @ W2 + b2 # Second layer output (32, 27)
    loss = F.cross_entropy(logits, Ytr[ix]) # this is the standard loss we have been using
    
    # Backward Pass
    for p in parameters:
        p.grad = None
    loss.backward()
    
    # Update using custom lr
    # lr = lrs[i]
    lr = 0.1 if i < 100000 else 0.01
    for p in parameters:
        p.data += -lr * p.grad

    # Track lr stats
    # lri.append(lre[i])
    stepi.append(i)
    lossi.append(loss.log10().item())

    if i % 25000 == 0 and i != 0:
        print(f"iter: {i}, averaged log loss: {sum(lossi[i-1000:i])/1000:.8f}")
# Out:
# iter: 25000, averaged log loss: 0.38010677
# iter: 50000, averaged log loss: 0.36986662
# iter: 75000, averaged log loss: 0.36020402
# iter: 100000, averaged log loss: 0.35570022
# iter: 125000, averaged log loss: 0.32760723
# iter: 150000, averaged log loss: 0.32411509
# iter: 175000, averaged log loss: 0.32364288
# iter: 200000, averaged log loss: 0.32466744
# iter: 225000, averaged log loss: 0.32348935

# %%
# EVALUATION

@torch.no_grad()
def split_loss(split):
    x, y = {
        'train': (Xtr, Ytr),
        'val': (Xdev, Ydev),
        'test': (Xte, Yte),
    }[split]
    emb = C[x]
    embcat = emb.view(emb.shape[0], -1)
    h = torch.tanh(embcat @ W1 + b1)
    logits = h @ W2 + b2
    loss = F.cross_entropy(logits, y)
    print(split, loss.item())

split_loss('train')
split_loss('val')
# Out:
# train 2.116136074066162
# val 2.1806585788726807

# %%
# SAMPLING FROM THE MODEL

for _ in range(20):
    out = []
    context = [0] * n
    while True:
        emb = C[torch.tensor([context])]
        h = torch.tanh(emb.view(1, -1) @ W1 + b1)
        logits = h @ W2 + b2
        probs = F.softmax(logits, dim=1)
        ix = torch.multinomial(probs, num_samples=1).item()
        context = context[1:] + [ix]
        out.append(ix)
        if ix == 0:
            break
    print(''.join(itos[i] for i in out), end=' ')
# Out:
# brarun. chie. jer. fino. ana. daison. diana. eva. aydor. jedelyn. zavamel. rayvon. rue. arn. kaylia. bree. ravee. lani. nie. tymar.

# %% [markdown]
# # Initialization
#
# If parameters are initialized at random, the value of the loss function evaluated at these initial parameters is usually quite large. Ideally, the model to be initialized in a way such that the probablility distribution it outputs given any context is uniform. Because the model has not learned anything, its output should be equivalent to a random guess. Under this assumption, we would expect a loss of $L = \log 27 \approx 3.3$. In other words, we are aiming to remove the "hockey stick" appearance of the loss graph.
#
# The first way to combat this is to set the biases of the output layer (i.e. logit layer) to zero to ensure zero mean. We can also scale the weights of this layer to ensure smaller variance, which will lead to a more uniform logit distribution. However, this multiplier must not be zero.
#
# Another issue is that a lot of the values output by the first hidden layer are very close to 1 or -1. This is because $\tanh$ is a "squashing" function, which is to say that values $x$ with roughly $|x| > 2$ have $|\tanh x| \approx 1$. Recall that $\frac{d}{d x} \tanh x = 1 - \tanh^2 x$, meaning these $x$ values have zero derivative and will effectively stop backpropagation through their respective neurons.
